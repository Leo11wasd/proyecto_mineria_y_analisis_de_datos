# %% [markdown]
# # Pruebas para el proyecto

# %% [markdown]
# En este notebook realizaré algunas pruebas para ver si tengo la configuración necesaria para desarrollar correctamente el proyecto.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\neto-\AppData\Local\Programs\Python\Python311\python.exe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

print("Todo funciona correctamente")
# Out:
# Todo funciona correctamente
